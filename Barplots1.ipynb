# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=['C++','C#','Python','Java','SQL']
y=[20,50,140,1,45]
plt.bar(x,y,color="pink",align="edge",edgecolor="gray",width=1,lw=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
